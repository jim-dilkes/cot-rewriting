# %%
import pandas as pd
import numpy as np
import json, os

pd.set_option("display.precision", 3)

results_dir = "./.archive/results/stage_1_rewrites"

use_tasks = [
        "gsm8k",
        "tracking_shuffled_objects_three_objects",
        "coinflip_eight",
        "prontoqa",
        "logiqa-en",
        "lsat-ar"
    ]

use_dirs = [
    # "PromptWithAnswerExtraction/gpt35_cot_instruct__baseline",
    "SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0",
    "SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07",
    "SolveValidateRewrite/gpt35_validate_framing__rewrite_T07",
    "SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07",
    "SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07",
    "SolveValidateRewrite/gpt35_validate_pattern__stg3",
    "SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3",
    # "PromptWithAnswerExtraction/gpt35_cot_instruct_reframed__baseline",
    # "PromptWithAnswerExtraction/gpt35_cot_instruct_reframed__baseline"
]

filepath = os.path.join(results_dir, "prontoqa","SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0", "results.json")

# %%
def extract_metrics(json_examples):
    dfs=[]
    for ex in json_examples:
        ex_dict = {}
        ex_dict['n_responses'] = ex['response_count']
        ex_dict['true_answer'] = ex['true_answer']
        ex_dict['predicted_answer'] = ex['predicted_answer']
        ex_dict['correct'] = ex['true_answer'] == ex['predicted_answer']
        for i,res in enumerate(ex['response_pairs']):
            ex_dict[f"answer_{i}"] = res['answer']
        ex_dict['answer_0_correct'] = ex_dict['answer_0'] == ex_dict['true_answer']
        dfs.append(pd.DataFrame(ex_dict,index=[ex['example_idx']]))
    df = pd.concat(dfs)
    
    # Create 'answer_1' column if it does not exist yet
    if 'answer_1' not in df.columns:
        df['answer_1'] = np.nan

    rewrite_perc = (~df['answer_1'].isna()).mean()

    # Get first rewrite decision accuracy
    rewrite_acc = pd.pivot_table(df, index='n_responses', columns='answer_0_correct', aggfunc='count', values='answer_0')
    rewrite_acc = rewrite_acc.div(rewrite_acc.sum(axis=0), axis=1)
    correct_pred_rewrites = 1-rewrite_acc[True].values[0]
    wrong_pred_rewrites = 1-rewrite_acc[False].values[0]
    
    # Percent of all first rewrite decision that were of wrong answers
    good_rewrites_perc = 1-df[~df['answer_1'].isna()]['answer_0_correct'].mean()



    # Get rewrite correction accuracy
    df_rewrites = df[~df['answer_1'].isna()]
    df_rewrite_conversions = df_rewrites.groupby(['answer_0_correct','correct']).size()
    correct_to_wrong_perc = df_rewrite_conversions[True][False] / df_rewrite_conversions[True].sum()
    wrong_to_correct_perc = df_rewrite_conversions[False][True] / df_rewrite_conversions[False].sum()    

    return {
        'pre_rewrite_acc': df['answer_0_correct'].mean(),
        'rewrite': rewrite_perc,
        'good_rewrites_share': good_rewrites_perc,
        'correct_pred_rewrites': correct_pred_rewrites,
        'wrong_pred_rewrites': wrong_pred_rewrites,
        'correct_to_wrong': correct_to_wrong_perc,
        'wrong_to_correct': wrong_to_correct_perc,
    }

# %%
dfs = []
for task in use_tasks:
    for dir in use_dirs:
        print(f"Task: {task}, Run: {os.path.join(results_dir, task, dir, 'results.json')}")
        # try to open results.json from each directory, if it exists
        try:
            with open(os.path.join(results_dir, task, dir, "results.json"), "r") as f:
                data_dict = json.load(f)
                metrics_dict = {
                    "Task": data_dict["Task"],
                    "Run": dir.split("/")[-1],
                    "N examples": data_dict["Number of examples"],
                    # "Number of correct": data_dict["Number of correct"],
                    "Accuracy": data_dict["Accuracy"],
                }
                metrics_dict |= extract_metrics(data_dict['examples'])
                dfs.append(pd.DataFrame(metrics_dict, index=[f"{task}_{dir.split('/')[-1]}"]))
        except FileNotFoundError:
            continue
df = pd.concat(dfs)
df = df.set_index(["Task", "Run"])
df
# Out:
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0\results.json
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07\results.json
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_validate_framing__rewrite_T07\results.json
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07\results.json
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07\results.json
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_validate_pattern__stg3\results.json
# Task: gsm8k, Run: ./.archive/results/stage_1_rewrites\gsm8k\SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_validate_framing__rewrite_T07\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_validate_pattern__stg3\results.json
# Task: tracking_shuffled_objects_three_objects, Run: ./.archive/results/stage_1_rewrites\tracking_shuffled_objects_three_objects\SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_validate_framing__rewrite_T07\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_validate_pattern__stg3\results.json
# Task: coinflip_eight, Run: ./.archive/results/stage_1_rewrites\coinflip_eight\SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_validate_framing__rewrite_T07\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_validate_pattern__stg3\results.json
# Task: prontoqa, Run: ./.archive/results/stage_1_rewrites\prontoqa\SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_validate_framing__rewrite_T07\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_validate_pattern__stg3\results.json
# Task: logiqa-en, Run: ./.archive/results/stage_1_rewrites\logiqa-en\SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_cot_instruct__rewrite_T07\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_validate_framing__rewrite_T07\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_validate_framing_rephrase_1__T07\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_validate_framing_rephrase_2__T07\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_validate_pattern__stg3\results.json
# Task: lsat-ar, Run: ./.archive/results/stage_1_rewrites\lsat-ar\SolveValidateRewrite/gpt35_validate_rewrite_pattern__stg3\results.json
#                                                                                 N examples  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                 250
#                                         gpt35_cot_instruct__rewrite_T07                250
#                                         gpt35_validate_framing__rewrite_T07            250
#                                         gpt35_validate_framing_rephrase_1__T07         250
#                                         gpt35_validate_framing_rephrase_2__T07         250
#                                         gpt35_validate_pattern__stg3                   250
#                                         gpt35_validate_rewrite_pattern__stg3           250
# prontoqa                                gpt35_cot_instruct__rewrite_T0                 250
#                                         gpt35_cot_instruct__rewrite_T07                250
#                                         gpt35_validate_framing__rewrite_T07            250
#                                         gpt35_validate_framing_rephrase_1__T07         250
#                                         gpt35_validate_framing_rephrase_2__T07         250
#                                         gpt35_validate_pattern__stg3                   250
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                 250
#                                         gpt35_cot_instruct__rewrite_T07                250
#                                         gpt35_validate_framing__rewrite_T07            250
#                                         gpt35_validate_pattern__stg3                   250
#                                         gpt35_validate_rewrite_pattern__stg3           250
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                 230
#                                         gpt35_cot_instruct__rewrite_T07                230
#                                         gpt35_validate_framing__rewrite_T07            230
#                                         gpt35_validate_pattern__stg3                   230
#
#                                                                                 Accuracy  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0             0.596
#                                         gpt35_cot_instruct__rewrite_T07            0.572
#                                         gpt35_validate_framing__rewrite_T07        0.612
#                                         gpt35_validate_framing_rephrase_1__T07     0.540
#                                         gpt35_validate_framing_rephrase_2__T07     0.568
#                                         gpt35_validate_pattern__stg3               0.768
#                                         gpt35_validate_rewrite_pattern__stg3       0.668
# prontoqa                                gpt35_cot_instruct__rewrite_T0             0.828
#                                         gpt35_cot_instruct__rewrite_T07            0.844
#                                         gpt35_validate_framing__rewrite_T07        0.848
#                                         gpt35_validate_framing_rephrase_1__T07     0.868
#                                         gpt35_validate_framing_rephrase_2__T07     0.792
#                                         gpt35_validate_pattern__stg3               0.876
# logiqa-en                               gpt35_cot_instruct__rewrite_T0             0.392
#                                         gpt35_cot_instruct__rewrite_T07            0.360
#                                         gpt35_validate_framing__rewrite_T07        0.400
#                                         gpt35_validate_pattern__stg3               0.400
#                                         gpt35_validate_rewrite_pattern__stg3       0.376
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0             0.204
#                                         gpt35_cot_instruct__rewrite_T07            0.226
#                                         gpt35_validate_framing__rewrite_T07        0.230
#                                         gpt35_validate_pattern__stg3               0.257
#
#                                                                                 pre_rewrite_acc  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                    0.636
#                                         gpt35_cot_instruct__rewrite_T07                   0.560
#                                         gpt35_validate_framing__rewrite_T07               0.596
#                                         gpt35_validate_framing_rephrase_1__T07            0.524
#                                         gpt35_validate_framing_rephrase_2__T07            0.552
#                                         gpt35_validate_pattern__stg3                      0.812
#                                         gpt35_validate_rewrite_pattern__stg3              0.704
# prontoqa                                gpt35_cot_instruct__rewrite_T0                    0.840
#                                         gpt35_cot_instruct__rewrite_T07                   0.852
#                                         gpt35_validate_framing__rewrite_T07               0.852
#                                         gpt35_validate_framing_rephrase_1__T07            0.872
#                                         gpt35_validate_framing_rephrase_2__T07            0.832
#                                         gpt35_validate_pattern__stg3                      0.900
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                    0.396
#                                         gpt35_cot_instruct__rewrite_T07                   0.360
#                                         gpt35_validate_framing__rewrite_T07               0.420
#                                         gpt35_validate_pattern__stg3                      0.400
#                                         gpt35_validate_rewrite_pattern__stg3              0.384
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                    0.217
#                                         gpt35_cot_instruct__rewrite_T07                   0.226
#                                         gpt35_validate_framing__rewrite_T07               0.226
#                                         gpt35_validate_pattern__stg3                      0.235
#
#                                                                                 rewrite  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0            0.500
#                                         gpt35_cot_instruct__rewrite_T07           0.496
#                                         gpt35_validate_framing__rewrite_T07       0.492
#                                         gpt35_validate_framing_rephrase_1__T07    0.508
#                                         gpt35_validate_framing_rephrase_2__T07    0.460
#                                         gpt35_validate_pattern__stg3              0.532
#                                         gpt35_validate_rewrite_pattern__stg3      0.560
# prontoqa                                gpt35_cot_instruct__rewrite_T0            0.168
#                                         gpt35_cot_instruct__rewrite_T07           0.132
#                                         gpt35_validate_framing__rewrite_T07       0.264
#                                         gpt35_validate_framing_rephrase_1__T07    0.288
#                                         gpt35_validate_framing_rephrase_2__T07    0.284
#                                         gpt35_validate_pattern__stg3              0.208
# logiqa-en                               gpt35_cot_instruct__rewrite_T0            0.092
#                                         gpt35_cot_instruct__rewrite_T07           0.092
#                                         gpt35_validate_framing__rewrite_T07       0.144
#                                         gpt35_validate_pattern__stg3              0.184
#                                         gpt35_validate_rewrite_pattern__stg3      0.456
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0            0.248
#                                         gpt35_cot_instruct__rewrite_T07           0.204
#                                         gpt35_validate_framing__rewrite_T07       0.322
#                                         gpt35_validate_pattern__stg3              0.339
#
#                                                                                 good_rewrites_share  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                        0.368
#                                         gpt35_cot_instruct__rewrite_T07                       0.484
#                                         gpt35_validate_framing__rewrite_T07                   0.512
#                                         gpt35_validate_framing_rephrase_1__T07                0.551
#                                         gpt35_validate_framing_rephrase_2__T07                0.565
#                                         gpt35_validate_pattern__stg3                          0.241
#                                         gpt35_validate_rewrite_pattern__stg3                  0.314
# prontoqa                                gpt35_cot_instruct__rewrite_T0                        0.119
#                                         gpt35_cot_instruct__rewrite_T07                       0.061
#                                         gpt35_validate_framing__rewrite_T07                   0.106
#                                         gpt35_validate_framing_rephrase_1__T07                0.153
#                                         gpt35_validate_framing_rephrase_2__T07                0.127
#                                         gpt35_validate_pattern__stg3                          0.077
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                        0.565
#                                         gpt35_cot_instruct__rewrite_T07                       0.696
#                                         gpt35_validate_framing__rewrite_T07                   0.611
#                                         gpt35_validate_pattern__stg3                          0.609
#                                         gpt35_validate_rewrite_pattern__stg3                  0.632
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                        0.754
#                                         gpt35_cot_instruct__rewrite_T07                       0.809
#                                         gpt35_validate_framing__rewrite_T07                   0.797
#                                         gpt35_validate_pattern__stg3                          0.795
#
#                                                                                 correct_pred_rewrites  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                          0.497
#                                         gpt35_cot_instruct__rewrite_T07                         0.457
#                                         gpt35_validate_framing__rewrite_T07                     0.403
#                                         gpt35_validate_framing_rephrase_1__T07                  0.435
#                                         gpt35_validate_framing_rephrase_2__T07                  0.362
#                                         gpt35_validate_pattern__stg3                            0.498
#                                         gpt35_validate_rewrite_pattern__stg3                    0.545
# prontoqa                                gpt35_cot_instruct__rewrite_T0                          0.176
#                                         gpt35_cot_instruct__rewrite_T07                         0.146
#                                         gpt35_validate_framing__rewrite_T07                     0.277
#                                         gpt35_validate_framing_rephrase_1__T07                  0.280
#                                         gpt35_validate_framing_rephrase_2__T07                  0.298
#                                         gpt35_validate_pattern__stg3                            0.213
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                          0.101
#                                         gpt35_cot_instruct__rewrite_T07                         0.078
#                                         gpt35_validate_framing__rewrite_T07                     0.133
#                                         gpt35_validate_pattern__stg3                            0.180
#                                         gpt35_validate_rewrite_pattern__stg3                    0.438
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                          0.280
#                                         gpt35_cot_instruct__rewrite_T07                         0.173
#                                         gpt35_validate_framing__rewrite_T07                     0.288
#                                         gpt35_validate_pattern__stg3                            0.296
#
#                                                                                 wrong_pred_rewrites  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                        0.505
#                                         gpt35_cot_instruct__rewrite_T07                       0.545
#                                         gpt35_validate_framing__rewrite_T07                   0.624
#                                         gpt35_validate_framing_rephrase_1__T07                0.588
#                                         gpt35_validate_framing_rephrase_2__T07                0.580
#                                         gpt35_validate_pattern__stg3                          0.681
#                                         gpt35_validate_rewrite_pattern__stg3                  0.595
# prontoqa                                gpt35_cot_instruct__rewrite_T0                        0.125
#                                         gpt35_cot_instruct__rewrite_T07                       0.054
#                                         gpt35_validate_framing__rewrite_T07                   0.189
#                                         gpt35_validate_framing_rephrase_1__T07                0.344
#                                         gpt35_validate_framing_rephrase_2__T07                0.214
#                                         gpt35_validate_pattern__stg3                          0.160
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                        0.086
#                                         gpt35_cot_instruct__rewrite_T07                       0.100
#                                         gpt35_validate_framing__rewrite_T07                   0.152
#                                         gpt35_validate_pattern__stg3                          0.187
#                                         gpt35_validate_rewrite_pattern__stg3                  0.468
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                        0.239
#                                         gpt35_cot_instruct__rewrite_T07                       0.213
#                                         gpt35_validate_framing__rewrite_T07                   0.331
#                                         gpt35_validate_pattern__stg3                          0.352
#
#                                                                                 correct_to_wrong  \
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                     0.203
#                                         gpt35_cot_instruct__rewrite_T07                    0.203
#                                         gpt35_validate_framing__rewrite_T07                0.233
#                                         gpt35_validate_framing_rephrase_1__T07             0.193
#                                         gpt35_validate_framing_rephrase_2__T07             0.160
#                                         gpt35_validate_pattern__stg3                       0.149
#                                         gpt35_validate_rewrite_pattern__stg3               0.208
# prontoqa                                gpt35_cot_instruct__rewrite_T0                     0.135
#                                         gpt35_cot_instruct__rewrite_T07                    0.097
#                                         gpt35_validate_framing__rewrite_T07                0.085
#                                         gpt35_validate_framing_rephrase_1__T07             0.148
#                                         gpt35_validate_framing_rephrase_2__T07             0.258
#                                         gpt35_validate_pattern__stg3                       0.167
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                     0.200
#                                         gpt35_cot_instruct__rewrite_T07                    0.143
#                                         gpt35_validate_framing__rewrite_T07                0.429
#                                         gpt35_validate_pattern__stg3                       0.111
#                                         gpt35_validate_rewrite_pattern__stg3               0.167
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                     0.429
#                                         gpt35_cot_instruct__rewrite_T07                    0.444
#                                         gpt35_validate_framing__rewrite_T07                0.333
#                                         gpt35_validate_pattern__stg3                       0.062
#
#                                                                                 wrong_to_correct
# Task                                    Run
# tracking_shuffled_objects/three_objects gpt35_cot_instruct__rewrite_T0                     0.130
#                                         gpt35_cot_instruct__rewrite_T07                    0.267
#                                         gpt35_validate_framing__rewrite_T07                0.286
#                                         gpt35_validate_framing_rephrase_1__T07             0.214
#                                         gpt35_validate_framing_rephrase_2__T07             0.185
#                                         gpt35_validate_pattern__stg3                       0.125
#                                         gpt35_validate_rewrite_pattern__stg3               0.250
# prontoqa                                gpt35_cot_instruct__rewrite_T0                     0.400
#                                         gpt35_cot_instruct__rewrite_T07                    0.500
#                                         gpt35_validate_framing__rewrite_T07                0.571
#                                         gpt35_validate_framing_rephrase_1__T07             0.727
#                                         gpt35_validate_framing_rephrase_2__T07             0.667
#                                         gpt35_validate_pattern__stg3                       0.500
# logiqa-en                               gpt35_cot_instruct__rewrite_T0                     0.077
#                                         gpt35_cot_instruct__rewrite_T07                    0.062
#                                         gpt35_validate_framing__rewrite_T07                0.045
#                                         gpt35_validate_pattern__stg3                       0.071
#                                         gpt35_validate_rewrite_pattern__stg3               0.069
# lsat-ar                                 gpt35_cot_instruct__rewrite_T0                     0.070
#                                         gpt35_cot_instruct__rewrite_T07                    0.105
#                                         gpt35_validate_framing__rewrite_T07                0.102
#                                         gpt35_validate_pattern__stg3                       0.097

# %%
filepath = os.path.join(results_dir, "prontoqa","SolveValidateRewrite/gpt35_cot_instruct__rewrite_T0", "results.json")
with open(filepath, "r") as f:
    data_dict = json.load(f)
    
total_examples = data_dict['Number of examples']
